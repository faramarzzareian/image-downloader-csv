# %%
import PIL
import os
from PIL import Image
f = r'./images'

# %%
os.listdir(f)

# %%
for file in os.listdir(f):
    f_img = f+"/"+file
    img = Image.open(f_img)
    img = img.resize((200,200))
    img.save(f_img)

# %%
b = pd.read_csv('./all_coins.csv')

# %%
modDf = a.dropna(how='any', subset=['front', 'back'])

# %%
modDf.to_csv('example.csv')

# %%
import pandas as pd
b = pd.read_csv('./example.csv')
# Out:
# C:\Users\faramarz\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import urllib.request
import requests
import os

j=0
for i in range(len(b.front)) :
     
    r = requests.get(b.front[i])
    path= b.front[i]
    r = requests.get(path)
    firstpos=path.rfind("/")
    lastpos=len(path)
    

    
    with open(r'C:/Users/faramarz/Desktop/classification images/images/' + path[firstpos+1:lastpos], "wb") as f:
        f.write(r.content)
    print(path[firstpos+1:lastpos])
    print(b.front[i])
# Out:
# 152-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/152-original.jpg
# 102-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/102-original.jpg
# 94-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/94-original.jpg
# 96-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/96-original.jpg
# 146-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/146-original.jpg
# 98-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/98-original.jpg
# 100-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/100-original.jpg
# 204-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/204-original.jpg
# 116-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/116-original.jpg
# 150-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/150-original.jpg
# 160-original.jpg
# https://en.numista.com/catalogue/photos/abkhazia/160-original.jpg
# 156-original.jpg
# ...
